# %%
import pandas as pd

# %%
#https://www.geeksforgeeks.org/python-pandas-split-strings-into-two-list-columns-using-str-split/

# %%
ZKI_Innovation = pd.read_csv("ZKI_Innovation.csv")
ZKI_Innovation
# Out:
#                                        location    price  \
# 0             ул.Эйнштейна,стр.1,Новоивановское  3730000
# 1             ул.Эйнштейна,стр.2,Новоивановское  4700000
# 2             ул.Эйнштейна,стр.1,Новоивановское  4850000
# 3                     ул.Эйнштейна,стр.2,Москва  4080000
# 4             ул.Эйнштейна,стр.1,Новоивановское  4800000
# 5             ул.Эйнштейна,стр.2,Новоивановское  4750000
# 6             ул.Эйнштейна,стр.1,Новоивановское  3200000
# 7             ул.Эйнштейна,стр.1,Новоивановское  6600000
# 8             ул.Эйнштейна,стр.1,Новоивановское  6399000
# 9                     ул.Эйнштейна,стр.3,Москва  3750000
# 10            ул.Эйнштейна,стр.1,Новоивановское  4600000
# 11            ул.Эйнштейна,стр.2,Новоивановское  3800000
# 12                    ул.Эйнштейна,стр.2,Москва  5300000
# 13              овациярабочийпос.Новоивановское  4100000
# 14            ул.Эйнштейна,стр.1,Новоивановское  6900000
# ...

# %%
# new data frame with split value columns 
#ZKI_Innovation["type_of_flat"]= ZKI_Innovation["type_of_flat"].str.split(",", n = 1, expand = True) 
# df display 
#ZKI_Innovation

# %%
# new data frame with split value columns 
new = ZKI_Innovation["type_of_flat"].str.split(",", n = 1, expand = True) 
  
# df display 
# making separate first name column from new data frame 
ZKI_Innovation["flat_type"]= new[0] 
  
# making separate last name column from new data frame 
ZKI_Innovation["size"]= new[1] 
new2 = ZKI_Innovation["size"].str.split(",", n = 1, expand = True) 

ZKI_Innovation["size"]= new2[0] 
ZKI_Innovation["level"]= new2[1] 
#ZKI_Innovation["level"]= new[2] 

ZKI_Innovation = ZKI_Innovation.drop(['type_of_flat'], axis=1)
ZKI_Innovation
# Out:
#                                        location    price     flat_type  \
# 0             ул.Эйнштейна,стр.1,Новоивановское  3730000        Студия
# 1             ул.Эйнштейна,стр.2,Новоивановское  4700000  1-к квартира
# 2             ул.Эйнштейна,стр.1,Новоивановское  4850000  1-к квартира
# 3                     ул.Эйнштейна,стр.2,Москва  4080000        Студия
# 4             ул.Эйнштейна,стр.1,Новоивановское  4800000  1-к квартира
# 5             ул.Эйнштейна,стр.2,Новоивановское  4750000  1-к квартира
# 6             ул.Эйнштейна,стр.1,Новоивановское  3200000        Студия
# 7             ул.Эйнштейна,стр.1,Новоивановское  6600000  2-к квартира
# 8             ул.Эйнштейна,стр.1,Новоивановское  6399000  2-к квартира
# 9                     ул.Эйнштейна,стр.3,Москва  3750000        Студия
# 10            ул.Эйнштейна,стр.1,Новоивановское  4600000  1-к квартира
# 11            ул.Эйнштейна,стр.2,Новоивановское  3800000        Студия
# ...

# %%
ZKI_Innovation['level'] = ZKI_Innovation['level'].str.replace("эт.", "", case = False) 
ZKI_Innovation['size'] = ZKI_Innovation['size'].str.replace("м²", "", case = False) 
ZKI_Innovation
# Out:
#                                        location    price     flat_type  \
# 0             ул.Эйнштейна,стр.1,Новоивановское  3730000        Студия
# 1             ул.Эйнштейна,стр.2,Новоивановское  4700000  1-к квартира
# 2             ул.Эйнштейна,стр.1,Новоивановское  4850000  1-к квартира
# 3                     ул.Эйнштейна,стр.2,Москва  4080000        Студия
# 4             ул.Эйнштейна,стр.1,Новоивановское  4800000  1-к квартира
# 5             ул.Эйнштейна,стр.2,Новоивановское  4750000  1-к квартира
# 6             ул.Эйнштейна,стр.1,Новоивановское  3200000        Студия
# 7             ул.Эйнштейна,стр.1,Новоивановское  6600000  2-к квартира
# 8             ул.Эйнштейна,стр.1,Новоивановское  6399000  2-к квартира
# 9                     ул.Эйнштейна,стр.3,Москва  3750000        Студия
# 10            ул.Эйнштейна,стр.1,Новоивановское  4600000  1-к квартира
# 11            ул.Эйнштейна,стр.2,Новоивановское  3800000        Студия
# ...

# %%
new3 = ZKI_Innovation["level"].str.split("/", n = 1, expand = True) 

ZKI_Innovation["flat_floor"]= new3[0] 
ZKI_Innovation["builing_floor"]= new3[1] 
ZKI_Innovation = ZKI_Innovation.drop(['level'], axis=1)
ZKI_Innovation
# Out:
#                                        location    price     flat_type  \
# 0             ул.Эйнштейна,стр.1,Новоивановское  3730000        Студия
# 1             ул.Эйнштейна,стр.2,Новоивановское  4700000  1-к квартира
# 2             ул.Эйнштейна,стр.1,Новоивановское  4850000  1-к квартира
# 3                     ул.Эйнштейна,стр.2,Москва  4080000        Студия
# 4             ул.Эйнштейна,стр.1,Новоивановское  4800000  1-к квартира
# 5             ул.Эйнштейна,стр.2,Новоивановское  4750000  1-к квартира
# 6             ул.Эйнштейна,стр.1,Новоивановское  3200000        Студия
# 7             ул.Эйнштейна,стр.1,Новоивановское  6600000  2-к квартира
# 8             ул.Эйнштейна,стр.1,Новоивановское  6399000  2-к квартира
# 9                     ул.Эйнштейна,стр.3,Москва  3750000        Студия
# 10            ул.Эйнштейна,стр.1,Новоивановское  4600000  1-к квартира
# 11            ул.Эйнштейна,стр.2,Новоивановское  3800000        Студия
# ...

# %%
ZKI_Innovation
# Out:
#                                        location    price     flat_type  \
# 0             ул.Эйнштейна,стр.1,Новоивановское  3730000        Студия
# 1             ул.Эйнштейна,стр.2,Новоивановское  4700000  1-к квартира
# 2             ул.Эйнштейна,стр.1,Новоивановское  4850000  1-к квартира
# 3                     ул.Эйнштейна,стр.2,Москва  4080000        Студия
# 4             ул.Эйнштейна,стр.1,Новоивановское  4800000  1-к квартира
# 5             ул.Эйнштейна,стр.2,Новоивановское  4750000  1-к квартира
# 6             ул.Эйнштейна,стр.1,Новоивановское  3200000        Студия
# 7             ул.Эйнштейна,стр.1,Новоивановское  6600000  2-к квартира
# 8             ул.Эйнштейна,стр.1,Новоивановское  6399000  2-к квартира
# 9                     ул.Эйнштейна,стр.3,Москва  3750000        Студия
# 10            ул.Эйнштейна,стр.1,Новоивановское  4600000  1-к квартира
# 11            ул.Эйнштейна,стр.2,Новоивановское  3800000        Студия
# ...

# %%
ZKI_Innovation.to_csv("ZKI_Innovation_clean.csv", index=False)

# %%
ZKI_Innovation = pd.read_csv("ZKI_Innovation_clean.csv")
ZKI_Innovation
# Out:
#                                        location    price     flat_type  size  \
# 0             ул.Эйнштейна,стр.1,Новоивановское  3730000        Студия  22.8
# 1             ул.Эйнштейна,стр.2,Новоивановское  4700000  1-к квартира  38.0
# 2             ул.Эйнштейна,стр.1,Новоивановское  4850000  1-к квартира  34.6
# 3                     ул.Эйнштейна,стр.2,Москва  4080000        Студия  25.5
# 4             ул.Эйнштейна,стр.1,Новоивановское  4800000  1-к квартира  34.2
# 5             ул.Эйнштейна,стр.2,Новоивановское  4750000  1-к квартира  34.6
# 6             ул.Эйнштейна,стр.1,Новоивановское  3200000        Студия  19.2
# 7             ул.Эйнштейна,стр.1,Новоивановское  6600000  2-к квартира  57.0
# 8             ул.Эйнштейна,стр.1,Новоивановское  6399000  2-к квартира  54.0
# 9                     ул.Эйнштейна,стр.3,Москва  3750000        Студия  23.0
# 10            ул.Эйнштейна,стр.1,Новоивановское  4600000  1-к квартира  32.0
# ...

# %%
new4 = ZKI_Innovation["location"].str.split(",", n = 1, expand = True) 

ZKI_Innovation["street"]= new4[0] 
ZKI_Innovation["number_of_building"]= new4[1] 
ZKI_Innovation = ZKI_Innovation.drop(['location'], axis=1)
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
new5 = ZKI_Innovation["number_of_building"].str.split(",", n = 1, expand = True) 

ZKI_Innovation["number_of_building"]= new5[0] 
ZKI_Innovation["building_area"]= new5[1] 
#ZKI_Innovation = ZKI_Innovation.drop(['location'], axis=1)
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
ZKI_Innovation.to_csv("ZKI_Innovation_cleaned_data2.csv", index=False)

# %%
ZKI_Innovation = pd.read_csv("ZKI_Innovation_cleaned_data2.csv")
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
#ZKI_Innovation = ZKI_Innovation.dropna()
#ZKI_Innovation

# %%
ZKI_Innovation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
# price                 30 non-null int64
# flat_type             30 non-null object
# size                  30 non-null float64
# flat_floor            30 non-null int64
# builing_floor         30 non-null int64
# street                30 non-null object
# number_of_building    29 non-null object
# building_area         29 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 2.0+ KB

# %%
ZKI_Innovation['Size (m²)'] = pd.to_numeric(ZKI_Innovation['size'], errors='coerce')
#ZKI_Innovation.dropna(subset=['Size (m²)'], inplace=True)
ZKI_Innovation = ZKI_Innovation.dropna(['size'])
# Out:
# C:\Users\79280\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: supplying multiple axes to axis is deprecated and will be removed in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-2ea83bde3e46> in <module>
#       1 ZKI_Innovation['Size (m²)'] = pd.to_numeric(ZKI_Innovation['size'], errors='coerce')
#       2 #ZKI_Innovation.dropna(subset=['Size (m²)'], inplace=True)
# ----> 3 ZKI_Innovation = ZKI_Innovation.dropna(['size'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4272             for ax in axis:
#    4273                 result = result.dropna(how=how, thresh=thresh, subset=subset,
# -> 4274                                        axis=ax)
#    4275         else:
# ...

# %%
ZKI_Innovation = ZKI_Innovation.dropna(subset=['size'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-154-72506dad8ce9> in <module>
# ----> 1 ZKI_Innovation = ZKI_Innovation.dropna(subset=['size'], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4283                 check = indices == -1
#    4284                 if check.any():
# -> 4285                     raise KeyError(list(np.compress(check, subset)))
#    4286                 agg_obj = self.take(indices, axis=agg_axis)
#    4287
#
# KeyError: ['size']

# %%
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
import re
re.compile('<title>(.*)</title>')

rooms = []
for h in ZKI_Innovation.flat_type:
    n = [(s) for s in re.findall(r'\d{1}', h)]
    rooms.append(n)
    
#roomT = pd.DataFrame(room)[0]

#rommT

# %%
#rooms

# %%
roomsT = pd.DataFrame(rooms)
roomsT
# Out:
#        0
# 0   None
# 1      1
# 2      1
# 3   None
# 4      1
# 5      1
# 6   None
# 7      2
# 8      2
# 9   None
# 10     1
# 11  None
# 12     1
# 13  None
# 14     2
# 15     1
# 16  None
# 17  None
# 18     1
# 19     1
# 20  None
# 21  None
# 22     1
# 23     2
# 24     2
# 25  None
# 26  None
# 27     1
# 28     2
# 29     2

# %%
roomsT[0].unique()
# Out:
# array([None, '1', '2'], dtype=object)

# %%
ZKI_Innovation['Rooms'] = roomsT
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
# number of properties rows
len(ZKI_Innovation['Rooms'])
# Out:
# 30

# %%
ZKI_Innovation.Rooms = ZKI_Innovation.Rooms.fillna(0)

# %%
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
ZKI_Innovation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 10 columns):
# price                 30 non-null int64
# flat_type             30 non-null object
# size                  30 non-null float64
# flat_floor            30 non-null int64
# builing_floor         30 non-null int64
# street                30 non-null object
# number_of_building    29 non-null object
# building_area         29 non-null object
# Size (m²)             30 non-null float64
# Rooms                 30 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.6+ KB

# %%
r=[]
for x in ZKI_Innovation['Rooms']:
    r.append(int(x))
   #r.append(int(x[1:]))
    
ZKI_Innovation['Rooms'] = r
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
ZKI_Innovation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 10 columns):
# price                 30 non-null int64
# flat_type             30 non-null object
# size                  30 non-null float64
# flat_floor            30 non-null int64
# builing_floor         30 non-null int64
# street                30 non-null object
# number_of_building    29 non-null object
# building_area         29 non-null object
# Size (m²)             30 non-null float64
# Rooms                 30 non-null int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 2.6+ KB

# %%
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
ZKI_Innovation['Price/m²'] = ZKI_Innovation['price']/ZKI_Innovation['Size (m²)']
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
ZKI_Innovation
# Out:
#       price     flat_type  size  flat_floor  builing_floor  \
# 0   3730000        Студия  22.8           7             24
# 1   4700000  1-к квартира  38.0          14             24
# 2   4850000  1-к квартира  34.6          11             15
# 3   4080000        Студия  25.5           2             14
# 4   4800000  1-к квартира  34.2          22             22
# 5   4750000  1-к квартира  34.6           3             15
# 6   3200000        Студия  19.2          14             24
# 7   6600000  2-к квартира  57.0          11             15
# 8   6399000  2-к квартира  54.0           3             22
# 9   3750000        Студия  23.0          15             16
# 10  4600000  1-к квартира  32.0          12             22
# 11  3800000        Студия  22.0          15             22
# 12  5300000  1-к квартира  40.0           6             22
# 13  4100000        Студия  23.0          16             25
# 14  6900000  2-к квартира  57.1          12             15
# ...

# %%
ZKI_Innovation = ZKI_Innovation.drop(['size'], axis=1)
ZKI_Innovation
# Out:
#       price     flat_type  flat_floor  builing_floor  \
# 0   3730000        Студия           7             24
# 1   4700000  1-к квартира          14             24
# 2   4850000  1-к квартира          11             15
# 3   4080000        Студия           2             14
# 4   4800000  1-к квартира          22             22
# 5   4750000  1-к квартира           3             15
# 6   3200000        Студия          14             24
# 7   6600000  2-к квартира          11             15
# 8   6399000  2-к квартира           3             22
# 9   3750000        Студия          15             16
# 10  4600000  1-к квартира          12             22
# 11  3800000        Студия          15             22
# 12  5300000  1-к квартира           6             22
# 13  4100000        Студия          16             25
# 14  6900000  2-к квартира          12             15
# 15  4850000  1-к квартира           3             22
# 16  3700000        Студия           5             14
# ...

# %%
ZKI_Innovation.to_csv("ZKI_Innovation_Price_divide_m².csv", index=False)

# %%
ZKI_Innovation.describe()
# Out:
#               price  flat_floor  builing_floor  Size (m²)      Rooms  \
# count  3.000000e+01   30.000000      30.000000  30.000000  30.000000
# mean   4.929633e+06   10.233333      19.733333  35.216667   0.833333
# std    1.340077e+06    5.787521       5.470506  12.537120   0.791478
# min    2.500000e+06    2.000000       3.000000  19.200000   0.000000
# 25%    3.800000e+06    4.250000      15.000000  24.025000   0.000000
# 50%    4.725000e+06   11.500000      22.000000  33.100000   1.000000
# 75%    5.850000e+06   14.750000      24.000000  41.600000   1.000000
# max    7.400000e+06   22.000000      25.000000  57.100000   2.000000
#
#             Price/m²
# count      30.000000
# mean   145253.757872
# std     22312.287182
# min     83333.333333
# 25%    133839.846508
# 50%    141604.010025
# 75%    162282.608696
# max    189743.589744

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
ZKI_Innovation.describe()
# Out:
#            price  flat_floor  builing_floor  Size (m²)  Rooms  Price/m²
# count      30.00       30.00          30.00      30.00  30.00     30.00
# mean  4929633.33       10.23          19.73      35.22   0.83 145253.76
# std   1340076.64        5.79           5.47      12.54   0.79  22312.29
# min   2500000.00        2.00           3.00      19.20   0.00  83333.33
# 25%   3800000.00        4.25          15.00      24.02   0.00 133839.85
# 50%   4725000.00       11.50          22.00      33.10   1.00 141604.01
# 75%   5850000.00       14.75          24.00      41.60   1.00 162282.61
# max   7400000.00       22.00          25.00      57.10   2.00 189743.59

# %%
ZKI_Innovation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 10 columns):
# price                 30 non-null int64
# flat_type             30 non-null object
# flat_floor            30 non-null int64
# builing_floor         30 non-null int64
# street                30 non-null object
# number_of_building    29 non-null object
# building_area         29 non-null object
# Size (m²)             30 non-null float64
# Rooms                 30 non-null int64
# Price/m²              30 non-null float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.8+ KB

# %% [markdown]
# # EDA

# %%
import seaborn as sns

# %%
ZKI_Innovation['size'] = ZKI_Innovation['Size (m²)']

# %%
sns.jointplot(x = "size", y = "price", data = ZKI_Innovation, color="purple")

# %%
sns.jointplot(x = "Price/m²", y = "price", data = ZKI_Innovation, color="purple")

# %%
sns.jointplot(x = "size", y = "Price/m²", data = ZKI_Innovation, color="purple")

# %%
import seaborn as sns
import scipy.stats as stats
from matplotlib import pyplot as plt
sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x = "size", y = "Price/m²", data = ZKI_Innovation, color="purple")
j.annotate(stats.pearsonr)
plt.show()

# %%
import seaborn as sns
import scipy.stats as stats
from matplotlib import pyplot as plt
sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x = "Price/m²", y = "price", data = ZKI_Innovation, color="purple")
j.annotate(stats.pearsonr)
plt.show()

# %%
import seaborn as sns
import scipy.stats as stats
from matplotlib import pyplot as plt
sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x = "size", y = "price", data = ZKI_Innovation, color="purple")
j.annotate(stats.pearsonr)
plt.show()

# %%
len(ZKI_Innovation[ZKI_Innovation['price'] < 3000000])
# Out:
# 1

# %%
ZKI_Innovation = ZKI_Innovation[ZKI_Innovation['price'] > 3000000]
ZKI_Innovation
# Out:
#       price     flat_type  flat_floor  builing_floor  \
# 0   3730000        Студия           7             24
# 1   4700000  1-к квартира          14             24
# 2   4850000  1-к квартира          11             15
# 3   4080000        Студия           2             14
# 4   4800000  1-к квартира          22             22
# 5   4750000  1-к квартира           3             15
# 6   3200000        Студия          14             24
# 7   6600000  2-к квартира          11             15
# 8   6399000  2-к квартира           3             22
# 9   3750000        Студия          15             16
# 10  4600000  1-к квартира          12             22
# 11  3800000        Студия          15             22
# 12  5300000  1-к квартира           6             22
# 13  4100000        Студия          16             25
# 14  6900000  2-к квартира          12             15
# 15  4850000  1-к квартира           3             22
# 16  3700000        Студия           5             14
# ...

# %%
ZKI_Innovation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 29
# Data columns (total 11 columns):
# price                 29 non-null int64
# flat_type             29 non-null object
# flat_floor            29 non-null int64
# builing_floor         29 non-null int64
# street                29 non-null object
# number_of_building    28 non-null object
# building_area         28 non-null object
# Size (m²)             29 non-null float64
# Rooms                 29 non-null int64
# Price/m²              29 non-null float64
# size                  29 non-null float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 2.7+ KB

# %%
ZKI_Innovation.describe()
# Out:
#            price  flat_floor  builing_floor  Size (m²)  Rooms  Price/m²  size
# count      29.00       29.00          29.00      29.00  29.00     29.00 29.00
# mean  5013413.79       10.48          20.31      35.40   0.86 147388.94 35.40
# std   1281345.32        5.72           4.54      12.72   0.79  19338.12 12.72
# min   3200000.00        2.00           8.00      19.20   0.00 115789.47 19.20
# 25%   3800000.00        5.00          15.00      24.00   0.00 134369.29 24.00
# 50%   4750000.00       12.00          22.00      34.20   1.00 142857.14 34.20
# 75%   6000000.00       15.00          24.00      42.00   1.00 163043.48 42.00
# max   7400000.00       22.00          25.00      57.10   2.00 189743.59 57.10

# %%
import seaborn as sns
import scipy.stats as stats
from matplotlib import pyplot as plt
sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x = "size", y = "price", data = ZKI_Innovation, color="purple")
j.annotate(stats.pearsonr)
plt.show()

# %%
len(ZKI_Innovation[ZKI_Innovation['Price/m²'] > 155000])
# Out:
# 10

# %%
len(ZKI_Innovation[ZKI_Innovation['Price/m²'] < 134000])
# Out:
# 7

# %%
ZKI_Innovation = ZKI_Innovation[ZKI_Innovation['Price/m²'] < 155000]
ZKI_Innovation
# Out:
#       price     flat_type  flat_floor  builing_floor         street  \
# 1   4700000  1-к квартира          14             24   ул.Эйнштейна
# 2   4850000  1-к квартира          11             15   ул.Эйнштейна
# 4   4800000  1-к квартира          22             22   ул.Эйнштейна
# 5   4750000  1-к квартира           3             15   ул.Эйнштейна
# 7   6600000  2-к квартира          11             15   ул.Эйнштейна
# 8   6399000  2-к квартира           3             22   ул.Эйнштейна
# 10  4600000  1-к квартира          12             22   ул.Эйнштейна
# 12  5300000  1-к квартира           6             22   ул.Эйнштейна
# 14  6900000  2-к квартира          12             15   ул.Эйнштейна
# 15  4850000  1-к квартира           3             22   ул.Эйнштейна
# 18  6000000  1-к квартира          14             22   ул.Эйнштейна
# 19  4600000  1-к квартира          16             22   ул.Эйнштейна
# 21  3690000        Студия           6             22   ул.Эйнштейна
# ...

# %%
ZKI_Innovation
# Out:
#       price     flat_type  flat_floor  builing_floor         street  \
# 1   4700000  1-к квартира          14             24   ул.Эйнштейна
# 2   4850000  1-к квартира          11             15   ул.Эйнштейна
# 4   4800000  1-к квартира          22             22   ул.Эйнштейна
# 5   4750000  1-к квартира           3             15   ул.Эйнштейна
# 7   6600000  2-к квартира          11             15   ул.Эйнштейна
# 8   6399000  2-к квартира           3             22   ул.Эйнштейна
# 10  4600000  1-к квартира          12             22   ул.Эйнштейна
# 12  5300000  1-к квартира           6             22   ул.Эйнштейна
# 14  6900000  2-к квартира          12             15   ул.Эйнштейна
# 15  4850000  1-к квартира           3             22   ул.Эйнштейна
# 18  6000000  1-к квартира          14             22   ул.Эйнштейна
# 19  4600000  1-к квартира          16             22   ул.Эйнштейна
# 21  3690000        Студия           6             22   ул.Эйнштейна
# ...

# %%
ZKI_Innovation.reset_index(inplace=True, drop=True)
ZKI_Innovation
# Out:
#       price     flat_type  flat_floor  builing_floor         street  \
# 0   4700000  1-к квартира          14             24   ул.Эйнштейна
# 1   4850000  1-к квартира          11             15   ул.Эйнштейна
# 2   4800000  1-к квартира          22             22   ул.Эйнштейна
# 3   4750000  1-к квартира           3             15   ул.Эйнштейна
# 4   6600000  2-к квартира          11             15   ул.Эйнштейна
# 5   6399000  2-к квартира           3             22   ул.Эйнштейна
# 6   4600000  1-к квартира          12             22   ул.Эйнштейна
# 7   5300000  1-к квартира           6             22   ул.Эйнштейна
# 8   6900000  2-к квартира          12             15   ул.Эйнштейна
# 9   4850000  1-к квартира           3             22   ул.Эйнштейна
# 10  6000000  1-к квартира          14             22   ул.Эйнштейна
# 11  4600000  1-к квартира          16             22   ул.Эйнштейна
# 12  3690000        Студия           6             22   ул.Эйнштейна
# ...

# %%
import seaborn as sns
import scipy.stats as stats
from matplotlib import pyplot as plt
sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x = "size", y = "Price/m²", data = ZKI_Innovation, color="purple")
j.annotate(stats.pearsonr)
plt.show()

# %%
import seaborn as sns
import scipy.stats as stats
from matplotlib import pyplot as plt
sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x = "Price/m²", y = "price", data = ZKI_Innovation, color="purple")
j.annotate(stats.pearsonr)
plt.show()

# %%
import seaborn as sns
import scipy.stats as stats
from matplotlib import pyplot as plt
sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x = "size", y = "price", data = ZKI_Innovation, color="purple")
j.annotate(stats.pearsonr)
plt.show()

# %%
sns.distplot(ZKI_Innovation['Price/m²'])
plt.show()

# %%
ZKI_Innovation.describe()
# Out:
#            price  flat_floor  builing_floor  Size (m²)  Rooms  Price/m²  size
# count      19.00       19.00          19.00      19.00  19.00     19.00 19.00
# mean  5582052.63       11.26          19.74      41.77   1.26 135608.61 41.77
# std   1209436.99        5.75           4.45      11.01   0.65  10322.22 11.01
# min   3690000.00        3.00           8.00      24.10   0.00 115789.47 24.10
# 25%   4725000.00        6.00          15.00      34.40   1.00 131634.62 34.40
# 50%   5300000.00       12.00          22.00      40.00   1.00 136911.49 40.00
# 75%   6700000.00       14.50          22.00      53.55   2.00 141604.01 53.55
# max   7400000.00       22.00          24.00      57.10   2.00 153112.03 57.10

# %%
ZKI_Innovation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
# price                 19 non-null int64
# flat_type             19 non-null object
# flat_floor            19 non-null int64
# builing_floor         19 non-null int64
# street                19 non-null object
# number_of_building    19 non-null object
# building_area         19 non-null object
# Size (m²)             19 non-null float64
# Rooms                 19 non-null int64
# Price/m²              19 non-null float64
# size                  19 non-null float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 1.7+ KB

# %%
cols = ['price','flat_floor','builing_floor','Rooms','Price/m²','size']
sns.pairplot(ZKI_Innovation[cols], size=5)
plt.show()

# %%
fig, ax =plt.subplots(6,1, figsize=(30,120))
sns.countplot(ZKI_Innovation['price'], ax=ax[0])
sns.countplot(ZKI_Innovation['flat_floor'], ax=ax[1])
sns.countplot(ZKI_Innovation['builing_floor'], ax=ax[2])
sns.countplot(ZKI_Innovation['Rooms'], ax=ax[3])
sns.countplot(ZKI_Innovation['Price/m²'], ax=ax[4])
sns.countplot(ZKI_Innovation['size'], ax=ax[5])


#ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=20, ha="right")
ax[4].set_xticklabels(ax[4].get_xticklabels(), rotation=90, ha="right")
plt.show()

# %%
plt.figure(figsize=(15,10))
ax = sns.boxplot(x='Rooms', y = 'price', data = ZKI_Innovation)
ax.tick_params(labelsize=13)
plt.show()

# %%
ZKI_Innovation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
# price                 19 non-null int64
# flat_type             19 non-null object
# flat_floor            19 non-null int64
# builing_floor         19 non-null int64
# street                19 non-null object
# number_of_building    19 non-null object
# building_area         19 non-null object
# Size (m²)             19 non-null float64
# Rooms                 19 non-null int64
# Price/m²              19 non-null float64
# size                  19 non-null float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 1.7+ KB

# %%
areas = ZKI_Innovation.loc[ZKI_Innovation['building_area'].isin(['Москва','Новоивановское'])]
areas
# Out:
#       price     flat_type  flat_floor  builing_floor        street  \
# 0   4700000  1-к квартира          14             24  ул.Эйнштейна
# 1   4850000  1-к квартира          11             15  ул.Эйнштейна
# 2   4800000  1-к квартира          22             22  ул.Эйнштейна
# 3   4750000  1-к квартира           3             15  ул.Эйнштейна
# 4   6600000  2-к квартира          11             15  ул.Эйнштейна
# 5   6399000  2-к квартира           3             22  ул.Эйнштейна
# 6   4600000  1-к квартира          12             22  ул.Эйнштейна
# 7   5300000  1-к квартира           6             22  ул.Эйнштейна
# 8   6900000  2-к квартира          12             15  ул.Эйнштейна
# 9   4850000  1-к квартира           3             22  ул.Эйнштейна
# 10  6000000  1-к квартира          14             22  ул.Эйнштейна
# 11  4600000  1-к квартира          16             22  ул.Эйнштейна
# 12  3690000        Студия           6             22  ул.Эйнштейна
# ...

# %%
plt.figure(figsize=(15,10))
ax = sns.boxplot(x='building_area', y = 'Price/m²', data = areas)
ax.set_xticklabels(ax.get_xticklabels(), rotation=50, ha="right")
ax.tick_params(labelsize=13)
plt.show()

# %%
areas.describe()
# Out:
#            price  flat_floor  builing_floor  Size (m²)  Rooms  Price/m²  size
# count      18.00       18.00          18.00      18.00  18.00     18.00 18.00
# mean  5481055.56       11.67          20.39      41.09   1.22 135543.33 41.09
# std   1159125.96        5.64           3.52      10.91   0.65  10617.44 10.91
# min   3690000.00        3.00          15.00      24.10   0.00 115789.47 24.10
# 25%   4712500.00        7.25          16.75      34.30   1.00 131201.92 34.30
# 50%   5075000.00       12.50          22.00      39.00   1.00 137097.36 39.00
# 75%   6549750.00       14.75          22.00      52.83   2.00 142230.58 52.83
# max   7350000.00       22.00          24.00      57.10   2.00 153112.03 57.10

# %%
areas.to_csv('areas.csv', index=False)

# %%
'price','flat_floor','builing_floor'

# %%
# new data frame with split value columns 
new = ZKI_Innovation["type_of_flat"].str.split(",", n = 1, expand = True) 
  
# df display 
# making separate first name column from new data frame 
ZKI_Innovation["flat_type"]= new[0] 
  
# making separate last name column from new data frame 
ZKI_Innovation["size"]= new[1] 
new2 = ZKI_Innovation["size"].str.split(",", n = 1, expand = True) 

ZKI_Innovation["size"]= new2[0] 
ZKI_Innovation["level"]= new2[1] 
#ZKI_Innovation["level"]= new[2] 

ZKI_Innovation = ZKI_Innovation.drop(['type_of_flat'], axis=1)
ZKI_Innovation

# %%
#https://www.geeksforgeeks.org/python-pandas-split-strings-into-two-list-columns-using-str-split/

# %%
#level3 = list()
#level3 = ZKI_Innovation['level']
#level3.replace('эт','')
#level3

ZKI_Innovation['level'] = ZKI_Innovation['level'].str.replace("эт.", "", case = False) 
ZKI_Innovation
#ZKI_Innovation['level'] = ZKI_Innovation['level'].replace('эт.','')
#ZKI_Innovation
# Out:
#                                        location    price  \
# 0             ул.Эйнштейна,стр.1,Новоивановское  3730000
# 1             ул.Эйнштейна,стр.2,Новоивановское  4700000
# 2             ул.Эйнштейна,стр.1,Новоивановское  4850000
# 3                     ул.Эйнштейна,стр.2,Москва  4080000
# 4             ул.Эйнштейна,стр.1,Новоивановское  4800000
# 5             ул.Эйнштейна,стр.2,Новоивановское  4750000
# 6             ул.Эйнштейна,стр.1,Новоивановское  3200000
# 7             ул.Эйнштейна,стр.1,Новоивановское  6600000
# 8             ул.Эйнштейна,стр.1,Новоивановское  6399000
# 9                     ул.Эйнштейна,стр.3,Москва  3750000
# 10            ул.Эйнштейна,стр.1,Новоивановское  4600000
# 11            ул.Эйнштейна,стр.2,Новоивановское  3800000
# 12                    ул.Эйнштейна,стр.2,Москва  5300000
# 13              овациярабочийпос.Новоивановское  4100000
# 14            ул.Эйнштейна,стр.1,Новоивановское  6900000
# ...

# %%
# new data frame with split value columns 
new = data["Name"].str.split(" ", n = 1, expand = True) 
  
# making separate first name column from new data frame 
data["First Name"]= new[0] 
  
# making separate last name column from new data frame 
data["Last Name"]= new[1]
